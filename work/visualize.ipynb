# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
gnss = pd.read_csv("/home/nakao/AdaptiveFEM/work/work1/data/GNSS_reduced.dat", delim_whitespace=True)
displacement = np.loadtxt("/home/nakao/AdaptiveFEM/work/work1/data/greens_function.dat")
ux = []
uy = []
uz = []
for i in range(displacement.shape[0]//3):
    ux.append(displacement[i*3])
    uy.append(displacement[i*3+1])
    uz.append(displacement[i*3+2])
ux = np.array(ux)
uy = np.array(uy)
uz = np.array(uz)

# %%
displacement
# Out:
# array([-0.00096753, -0.00038615,  0.00031538,  0.00187357,  0.00104301,
#         0.0014743 ,  0.02175822, -0.0075473 ,  0.01050366,  0.00031661,
#         0.00108315,  0.00112786,  0.00040728, -0.00221367, -0.00191662,
#         0.010401  , -0.01090595,  0.00464348,  0.00334028, -0.00134963,
#        -0.00156067,  0.00042382, -0.00365034, -0.00511947,  0.02205238,
#         0.00556595,  0.01685402,  0.02942853,  0.00025027, -0.01554729,
#         0.01219495,  0.00356815, -0.00433439,  0.01239831, -0.03487986,
#         0.02786148,  0.00436621, -0.00421091,  0.00096015,  0.00095074,
#        -0.00153347, -0.00135171,  0.00659189, -0.00453192, -0.00446864,
#         0.01055653, -0.00196934, -0.00447505,  0.00022896,  0.00435778,
#         0.0032061 ])

# %%
fig, ax = plt.subplots()
ax.scatter(gnss["lon"], gnss["lat"])
ax.quiver(gnss["lon"], gnss["lat"], ux, uy)

# %%
dat = np.fromfile("/home/nakao/AdaptiveFEM/work/work1/displacement/0001_obs.bin")

# %%
dat
# Out:
# array([1.04290091e-17, 3.13191003e-18, 5.00931392e-18, ...,
#        3.03315168e-17, 7.54441463e-18, 1.05535765e-17])
